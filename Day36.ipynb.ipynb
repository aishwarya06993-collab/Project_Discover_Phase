# %% [markdown]
# ### Student Diary Entry (Days 36)
#
# During the last three days, I focused on converting my ideas into practical project steps.
# I analyzed the Sustainable Development Goals framework and connected it with my project topic.
# By studying research reports and conducting small surveys, I gathered useful insights about the problem.
# This helped me narrow a broad concept into a clear and focused problem statement.
#
# I applied the “5 Whys” technique to understand the root cause behind the issue.
# Through this process, I realized that the visible problem was only a symptom of a deeper challenge.
# I also identified different stakeholders such as users, service providers, and local authorities.
# Mapping their needs helped me better understand how the solution should be designed.
#
# One difficulty I faced was trying to address too many issues at once in the beginning.
# After feedback, I simplified my idea and focused on one core problem.
# Another challenge was finding accurate local data related to the issue.
# To overcome this, I used data from similar cities and combined it with my survey responses.
#
#     ### Student Diary Entry (Days 36)
#
# - Worked on refining my Heart Disease Detection project idea and defining the main objective.
# - Studied how machine learning can help in early prediction of heart disease using medical data.
# - Collected and reviewed datasets related to heart health parameters such as age, cholesterol, and blood pressure.
# - Analyzed the dataset to understand which features influence heart disease prediction.
#
# - Learned how to frame a clear problem statement for predicting heart disease risk.
# - Explored basic data preprocessing techniques like cleaning missing values and organizing data.
# - Understood the importance of feature selection for improving model accuracy.
# - Planned the next steps for building and testing machine learning models.
#
# - Faced difficulty in understanding some medical attributes in the dataset.
# - Some data values were missing or inconsistent which required preprocessing.
# - Needed to research more about healthcare datasets to ensure reliability.
# - Planning to validate results using different machine learning algorithms.
